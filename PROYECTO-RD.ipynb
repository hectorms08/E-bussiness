# %%
from bs4 import BeautifulSoup as bs

# %%
import requests as rq
import bs4

# %%
bs4.__version__
# Out:
# '4.12.2'

# %%
url = 'https://tienda.falabella.com.pe/falabella-pe/category/cat11380473/Arboles-de-navidad'

# %%
html = rq.get(url).content.decode('utf-8')
type(html)
# Out:
# str

# %%
print(html)
# Out:
# <!DOCTYPE html><html lang="es"><head><style>body { margin: 0 } /* custom! */</style><meta property="al:ios:url" content="tienda.falabella.com.pe://falabella-pe/category/cat11380473/Arboles-de-navidad"/><meta property="al:ios:app_store_id" content="947145705"/><meta property="al:ios:app_name" content="Falabella - Compra Online"/><meta property="al:android:url" content="https://tienda.falabella.com.pe/falabella-pe/category/cat11380473/Arboles-de-navidad"/><meta property="al:android:app_name" content="Falabella - Compra Online"/><meta property="al:android:package" content="com.falabella.falabellaApp"/><meta property="al:web:url" content="https://tienda.falabella.com.pe/falabella-pe/category/cat11380473/Arboles-de-navidad"/><meta charSet="utf-8" class="next-head"/><script class="next-head">
#         (function(w,d,s,l,i){w[l]=w[l]||[];
#             w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
# ...
